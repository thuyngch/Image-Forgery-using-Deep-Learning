# %% [markdown]
# # Libraries

# %%
# %load_ext autoreload
# %autoreload 2

import os, torch, sys
from PIL import Image
import numpy as np
from time import time
from torchsummary import summary
from multiprocessing import cpu_count
sys.path.append("../")

from utils import image
from utils.data import NumpyImageLoader

# %%
IMAGE_FILE = "/media/antiaegis/storing/datasets/CASIA2/Tp/Tp_D_CND_S_N_ani00073_ani00068_00193.tif"

# %% [markdown]
# # mobilenetv2_orig

# %%
from utils.MobileNetV2_pretrained_imagenet import MobileNetV2

params = {}
params["channel"] = "YCbCr"
params["threshold"] = 0.65
params["training_log_dir"] = "../backup/MBN2-YCbCr/checkpoints/"

MODEL_FILE = os.path.join(params["training_log_dir"], "model.ckpt")
DEVICE = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

model = MobileNetV2(n_class=2, input_size=64, width_mult=1.0).to(device=DEVICE)
model.load(model_file=MODEL_FILE)
model.eval()
summary(model, input_size=(3, 64, 64))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1           [-1, 32, 32, 32]             864
#        BatchNorm2d-2           [-1, 32, 32, 32]              64
#              ReLU6-3           [-1, 32, 32, 32]               0
#             Conv2d-4           [-1, 32, 32, 32]             288
#        BatchNorm2d-5           [-1, 32, 32, 32]              64
#              ReLU6-6           [-1, 32, 32, 32]               0
#             Conv2d-7           [-1, 16, 32, 32]             512
#        BatchNorm2d-8           [-1, 16, 32, 32]              32
#   InvertedResidual-9           [-1, 16, 32, 32]               0
#            Conv2d-10           [-1, 96, 32, 32]           1,536
#       BatchNorm2d-11           [-1, 96, 32, 32]             192
#             ReLU6-12           [-1, 96, 32, 32]               0
#            Conv2d-13           [-1, 96, 16, 16]             864
#       BatchNorm2d-14           [-1, 96, 16, 16]             192
#             ReLU6-15           [-1, 96, 16, 16]               0
#            Conv2d-16           [-1, 24, 16, 16]           2,304
#       BatchNorm2d-17           [-1, 24, 16, 16]              48
#  InvertedResidual-18           [-1, 24, 16, 16]               0
#            Conv2d-19          [-1, 144, 16, 16]           3,456
#       BatchNorm2d-20          [-1, 144, 16, 16]             288
#             ReLU6-21          [-1, 144, 16, 16]               0
#            Conv2d-22          [-1, 144, 16, 16]           1,296
#       BatchNorm2d-23          [-1, 144, 16, 16]             288
#             ReLU6-24          [-1, 144, 16, 16]               0
#            Conv2d-25           [-1, 24, 16, 16]           3,456
#       BatchNorm2d-26           [-1, 24, 16, 16]              48
#  InvertedResidual-27           [-1, 24, 16, 16]               0
#            Conv2d-28          [-1, 144, 16, 16]           3,456
#       BatchNorm2d-29          [-1, 144, 16, 16]             288
#             ReLU6-30          [-1, 144, 16, 16]               0
#            Conv2d-31            [-1, 144, 8, 8]           1,296
#       BatchNorm2d-32            [-1, 144, 8, 8]             288
#             ReLU6-33            [-1, 144, 8, 8]               0
#            Conv2d-34             [-1, 32, 8, 8]           4,608
#       BatchNorm2d-35             [-1, 32, 8, 8]              64
#  InvertedResidual-36             [-1, 32, 8, 8]               0
#            Conv2d-37            [-1, 192, 8, 8]           6,144
#       BatchNorm2d-38            [-1, 192, 8, 8]             384
#             ReLU6-39            [-1, 192, 8, 8]               0
#            Conv2d-40            [-1, 192, 8, 8]           1,728
#       BatchNorm2d-41            [-1, 192, 8, 8]             384
#             ReLU6-42            [-1, 192, 8, 8]               0
#            Conv2d-43             [-1, 32, 8, 8]           6,144
#       BatchNorm2d-44             [-1, 32, 8, 8]              64
#  InvertedResidual-45             [-1, 32, 8, 8]               0
#            Conv2d-46            [-1, 192, 8, 8]           6,144
#       BatchNorm2d-47            [-1, 192, 8, 8]             384
#             ReLU6-48            [-1, 192, 8, 8]               0
#            Conv2d-49            [-1, 192, 8, 8]           1,728
#       BatchNorm2d-50            [-1, 192, 8, 8]             384
#             ReLU6-51            [-1, 192, 8, 8]               0
#            Conv2d-52             [-1, 32, 8, 8]           6,144
#       BatchNorm2d-53             [-1, 32, 8, 8]              64
#  InvertedResidual-54             [-1, 32, 8, 8]               0
#            Conv2d-55            [-1, 192, 8, 8]           6,144
#       BatchNorm2d-56            [-1, 192, 8, 8]             384
#             ReLU6-57            [-1, 192, 8, 8]               0
#            Conv2d-58            [-1, 192, 4, 4]           1,728
#       BatchNorm2d-59            [-1, 192, 4, 4]             384
#             ReLU6-60            [-1, 192, 4, 4]               0
#            Conv2d-61             [-1, 64, 4, 4]          12,288
#       BatchNorm2d-62             [-1, 64, 4, 4]             128
#  InvertedResidual-63             [-1, 64, 4, 4]               0
#            Conv2d-64            [-1, 384, 4, 4]          24,576
#       BatchNorm2d-65            [-1, 384, 4, 4]             768
#             ReLU6-66            [-1, 384, 4, 4]               0
#            Conv2d-67            [-1, 384, 4, 4]           3,456
#       BatchNorm2d-68            [-1, 384, 4, 4]             768
#             ReLU6-69            [-1, 384, 4, 4]               0
#            Conv2d-70             [-1, 64, 4, 4]          24,576
#       BatchNorm2d-71             [-1, 64, 4, 4]             128
#  InvertedResidual-72             [-1, 64, 4, 4]               0
#            Conv2d-73            [-1, 384, 4, 4]          24,576
#       BatchNorm2d-74            [-1, 384, 4, 4]             768
#             ReLU6-75            [-1, 384, 4, 4]               0
#            Conv2d-76            [-1, 384, 4, 4]           3,456
#       BatchNorm2d-77            [-1, 384, 4, 4]             768
#             ReLU6-78            [-1, 384, 4, 4]               0
#            Conv2d-79             [-1, 64, 4, 4]          24,576
#       BatchNorm2d-80             [-1, 64, 4, 4]             128
#  InvertedResidual-81             [-1, 64, 4, 4]               0
#            Conv2d-82            [-1, 384, 4, 4]          24,576
#       BatchNorm2d-83            [-1, 384, 4, 4]             768
#             ReLU6-84            [-1, 384, 4, 4]               0
#            Conv2d-85            [-1, 384, 4, 4]           3,456
#       BatchNorm2d-86            [-1, 384, 4, 4]             768
#             ReLU6-87            [-1, 384, 4, 4]               0
#            Conv2d-88             [-1, 64, 4, 4]          24,576
#       BatchNorm2d-89             [-1, 64, 4, 4]             128
#  InvertedResidual-90             [-1, 64, 4, 4]               0
#            Conv2d-91            [-1, 384, 4, 4]          24,576
#       BatchNorm2d-92            [-1, 384, 4, 4]             768
#             ReLU6-93            [-1, 384, 4, 4]               0
#            Conv2d-94            [-1, 384, 4, 4]           3,456
#       BatchNorm2d-95            [-1, 384, 4, 4]             768
#             ReLU6-96            [-1, 384, 4, 4]               0
#            Conv2d-97             [-1, 96, 4, 4]          36,864
#       BatchNorm2d-98             [-1, 96, 4, 4]             192
#  InvertedResidual-99             [-1, 96, 4, 4]               0
#           Conv2d-100            [-1, 576, 4, 4]          55,296
#      BatchNorm2d-101            [-1, 576, 4, 4]           1,152
#            ReLU6-102            [-1, 576, 4, 4]               0
#           Conv2d-103            [-1, 576, 4, 4]           5,184
#      BatchNorm2d-104            [-1, 576, 4, 4]           1,152
#            ReLU6-105            [-1, 576, 4, 4]               0
#           Conv2d-106             [-1, 96, 4, 4]          55,296
#      BatchNorm2d-107             [-1, 96, 4, 4]             192
# InvertedResidual-108             [-1, 96, 4, 4]               0
#           Conv2d-109            [-1, 576, 4, 4]          55,296
#      BatchNorm2d-110            [-1, 576, 4, 4]           1,152
#            ReLU6-111            [-1, 576, 4, 4]               0
#           Conv2d-112            [-1, 576, 4, 4]           5,184
#      BatchNorm2d-113            [-1, 576, 4, 4]           1,152
#            ReLU6-114            [-1, 576, 4, 4]               0
#           Conv2d-115             [-1, 96, 4, 4]          55,296
#      BatchNorm2d-116             [-1, 96, 4, 4]             192
# InvertedResidual-117             [-1, 96, 4, 4]               0
#           Conv2d-118            [-1, 576, 4, 4]          55,296
#      BatchNorm2d-119            [-1, 576, 4, 4]           1,152
#            ReLU6-120            [-1, 576, 4, 4]               0
#           Conv2d-121            [-1, 576, 2, 2]           5,184
#      BatchNorm2d-122            [-1, 576, 2, 2]           1,152
#            ReLU6-123            [-1, 576, 2, 2]               0
#           Conv2d-124            [-1, 160, 2, 2]          92,160
#      BatchNorm2d-125            [-1, 160, 2, 2]             320
# InvertedResidual-126            [-1, 160, 2, 2]               0
#           Conv2d-127            [-1, 960, 2, 2]         153,600
#      BatchNorm2d-128            [-1, 960, 2, 2]           1,920
#            ReLU6-129            [-1, 960, 2, 2]               0
#           Conv2d-130            [-1, 960, 2, 2]           8,640
#      BatchNorm2d-131            [-1, 960, 2, 2]           1,920
#            ReLU6-132            [-1, 960, 2, 2]               0
#           Conv2d-133            [-1, 160, 2, 2]         153,600
#      BatchNorm2d-134            [-1, 160, 2, 2]             320
# InvertedResidual-135            [-1, 160, 2, 2]               0
#           Conv2d-136            [-1, 960, 2, 2]         153,600
#      BatchNorm2d-137            [-1, 960, 2, 2]           1,920
#            ReLU6-138            [-1, 960, 2, 2]               0
#           Conv2d-139            [-1, 960, 2, 2]           8,640
#      BatchNorm2d-140            [-1, 960, 2, 2]           1,920
#            ReLU6-141            [-1, 960, 2, 2]               0
#           Conv2d-142            [-1, 160, 2, 2]         153,600
#      BatchNorm2d-143            [-1, 160, 2, 2]             320
# InvertedResidual-144            [-1, 160, 2, 2]               0
#           Conv2d-145            [-1, 960, 2, 2]         153,600
#      BatchNorm2d-146            [-1, 960, 2, 2]           1,920
#            ReLU6-147            [-1, 960, 2, 2]               0
#           Conv2d-148            [-1, 960, 2, 2]           8,640
#      BatchNorm2d-149            [-1, 960, 2, 2]           1,920
#            ReLU6-150            [-1, 960, 2, 2]               0
#           Conv2d-151            [-1, 320, 2, 2]         307,200
#      BatchNorm2d-152            [-1, 320, 2, 2]             640
# InvertedResidual-153            [-1, 320, 2, 2]               0
#           Conv2d-154           [-1, 1280, 2, 2]         409,600
#      BatchNorm2d-155           [-1, 1280, 2, 2]           2,560
#            ReLU6-156           [-1, 1280, 2, 2]               0
#          Dropout-157                 [-1, 1280]               0
#           Linear-158                    [-1, 2]           2,562
# ================================================================
# Total params: 2,226,434
# Trainable params: 2,226,434
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.05
# Forward/backward pass size (MB): 12.49
# Params size (MB): 8.49
# Estimated Total Size (MB): 21.03
# ----------------------------------------------------------------

# %%
# Load data
img = np.array(Image.open(IMAGE_FILE).convert("YCbCr"))
coords, _, _ = image.slide2d(sz=img.shape[:2], K=64, S=32)
patches = image.crop_patches( img=img, coords=coords, patch_sz=64)
loader = NumpyImageLoader( ndarray_data=patches, batch_size=1, n_workers=cpu_count(), pin_memory=True, shuffle=False).loader

# Measure time
times = []
for X in loader:
    X = X[0].to(DEVICE)
    start_time = time()
    logits = model(X)
    end_time = time()
    times.append(end_time-start_time)
    
print("Runtime: %.1f[ms]" % (1000*sum(times)/len(times)))
# Out:
# Runtime: 5.6[ms]

# %% [markdown]
# # mobilenetv2_pretrained_imagenet

# %%
from utils.MobileNetV2_pretrained_imagenet import MobileNetV2

params["channel"] = "YCbCr"
params["threshold"] = 0.80
params["training_log_dir"] = "../backup/MBN2-pre-YCbCr/checkpoints/"

MODEL_FILE = os.path.join(params["training_log_dir"], "model.ckpt")
DEVICE = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

model = MobileNetV2(n_class=2, input_size=64, width_mult=1.0).to(DEVICE)
model.load(model_file=MODEL_FILE)
model.eval()
summary(model, input_size=(3, 64, 64))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1           [-1, 32, 32, 32]             864
#        BatchNorm2d-2           [-1, 32, 32, 32]              64
#              ReLU6-3           [-1, 32, 32, 32]               0
#             Conv2d-4           [-1, 32, 32, 32]             288
#        BatchNorm2d-5           [-1, 32, 32, 32]              64
#              ReLU6-6           [-1, 32, 32, 32]               0
#             Conv2d-7           [-1, 16, 32, 32]             512
#        BatchNorm2d-8           [-1, 16, 32, 32]              32
#   InvertedResidual-9           [-1, 16, 32, 32]               0
#            Conv2d-10           [-1, 96, 32, 32]           1,536
#       BatchNorm2d-11           [-1, 96, 32, 32]             192
#             ReLU6-12           [-1, 96, 32, 32]               0
#            Conv2d-13           [-1, 96, 16, 16]             864
#       BatchNorm2d-14           [-1, 96, 16, 16]             192
#             ReLU6-15           [-1, 96, 16, 16]               0
#            Conv2d-16           [-1, 24, 16, 16]           2,304
#       BatchNorm2d-17           [-1, 24, 16, 16]              48
#  InvertedResidual-18           [-1, 24, 16, 16]               0
#            Conv2d-19          [-1, 144, 16, 16]           3,456
#       BatchNorm2d-20          [-1, 144, 16, 16]             288
#             ReLU6-21          [-1, 144, 16, 16]               0
#            Conv2d-22          [-1, 144, 16, 16]           1,296
#       BatchNorm2d-23          [-1, 144, 16, 16]             288
#             ReLU6-24          [-1, 144, 16, 16]               0
#            Conv2d-25           [-1, 24, 16, 16]           3,456
#       BatchNorm2d-26           [-1, 24, 16, 16]              48
#  InvertedResidual-27           [-1, 24, 16, 16]               0
#            Conv2d-28          [-1, 144, 16, 16]           3,456
#       BatchNorm2d-29          [-1, 144, 16, 16]             288
#             ReLU6-30          [-1, 144, 16, 16]               0
#            Conv2d-31            [-1, 144, 8, 8]           1,296
#       BatchNorm2d-32            [-1, 144, 8, 8]             288
#             ReLU6-33            [-1, 144, 8, 8]               0
#            Conv2d-34             [-1, 32, 8, 8]           4,608
#       BatchNorm2d-35             [-1, 32, 8, 8]              64
#  InvertedResidual-36             [-1, 32, 8, 8]               0
#            Conv2d-37            [-1, 192, 8, 8]           6,144
#       BatchNorm2d-38            [-1, 192, 8, 8]             384
#             ReLU6-39            [-1, 192, 8, 8]               0
#            Conv2d-40            [-1, 192, 8, 8]           1,728
#       BatchNorm2d-41            [-1, 192, 8, 8]             384
#             ReLU6-42            [-1, 192, 8, 8]               0
#            Conv2d-43             [-1, 32, 8, 8]           6,144
#       BatchNorm2d-44             [-1, 32, 8, 8]              64
#  InvertedResidual-45             [-1, 32, 8, 8]               0
#            Conv2d-46            [-1, 192, 8, 8]           6,144
#       BatchNorm2d-47            [-1, 192, 8, 8]             384
#             ReLU6-48            [-1, 192, 8, 8]               0
#            Conv2d-49            [-1, 192, 8, 8]           1,728
#       BatchNorm2d-50            [-1, 192, 8, 8]             384
#             ReLU6-51            [-1, 192, 8, 8]               0
#            Conv2d-52             [-1, 32, 8, 8]           6,144
#       BatchNorm2d-53             [-1, 32, 8, 8]              64
#  InvertedResidual-54             [-1, 32, 8, 8]               0
#            Conv2d-55            [-1, 192, 8, 8]           6,144
#       BatchNorm2d-56            [-1, 192, 8, 8]             384
#             ReLU6-57            [-1, 192, 8, 8]               0
#            Conv2d-58            [-1, 192, 4, 4]           1,728
#       BatchNorm2d-59            [-1, 192, 4, 4]             384
#             ReLU6-60            [-1, 192, 4, 4]               0
#            Conv2d-61             [-1, 64, 4, 4]          12,288
#       BatchNorm2d-62             [-1, 64, 4, 4]             128
#  InvertedResidual-63             [-1, 64, 4, 4]               0
#            Conv2d-64            [-1, 384, 4, 4]          24,576
#       BatchNorm2d-65            [-1, 384, 4, 4]             768
#             ReLU6-66            [-1, 384, 4, 4]               0
#            Conv2d-67            [-1, 384, 4, 4]           3,456
#       BatchNorm2d-68            [-1, 384, 4, 4]             768
#             ReLU6-69            [-1, 384, 4, 4]               0
#            Conv2d-70             [-1, 64, 4, 4]          24,576
#       BatchNorm2d-71             [-1, 64, 4, 4]             128
#  InvertedResidual-72             [-1, 64, 4, 4]               0
#            Conv2d-73            [-1, 384, 4, 4]          24,576
#       BatchNorm2d-74            [-1, 384, 4, 4]             768
#             ReLU6-75            [-1, 384, 4, 4]               0
#            Conv2d-76            [-1, 384, 4, 4]           3,456
#       BatchNorm2d-77            [-1, 384, 4, 4]             768
#             ReLU6-78            [-1, 384, 4, 4]               0
#            Conv2d-79             [-1, 64, 4, 4]          24,576
#       BatchNorm2d-80             [-1, 64, 4, 4]             128
#  InvertedResidual-81             [-1, 64, 4, 4]               0
#            Conv2d-82            [-1, 384, 4, 4]          24,576
#       BatchNorm2d-83            [-1, 384, 4, 4]             768
#             ReLU6-84            [-1, 384, 4, 4]               0
#            Conv2d-85            [-1, 384, 4, 4]           3,456
#       BatchNorm2d-86            [-1, 384, 4, 4]             768
#             ReLU6-87            [-1, 384, 4, 4]               0
#            Conv2d-88             [-1, 64, 4, 4]          24,576
#       BatchNorm2d-89             [-1, 64, 4, 4]             128
#  InvertedResidual-90             [-1, 64, 4, 4]               0
#            Conv2d-91            [-1, 384, 4, 4]          24,576
#       BatchNorm2d-92            [-1, 384, 4, 4]             768
#             ReLU6-93            [-1, 384, 4, 4]               0
#            Conv2d-94            [-1, 384, 4, 4]           3,456
#       BatchNorm2d-95            [-1, 384, 4, 4]             768
#             ReLU6-96            [-1, 384, 4, 4]               0
#            Conv2d-97             [-1, 96, 4, 4]          36,864
#       BatchNorm2d-98             [-1, 96, 4, 4]             192
#  InvertedResidual-99             [-1, 96, 4, 4]               0
#           Conv2d-100            [-1, 576, 4, 4]          55,296
#      BatchNorm2d-101            [-1, 576, 4, 4]           1,152
#            ReLU6-102            [-1, 576, 4, 4]               0
#           Conv2d-103            [-1, 576, 4, 4]           5,184
#      BatchNorm2d-104            [-1, 576, 4, 4]           1,152
#            ReLU6-105            [-1, 576, 4, 4]               0
#           Conv2d-106             [-1, 96, 4, 4]          55,296
#      BatchNorm2d-107             [-1, 96, 4, 4]             192
# InvertedResidual-108             [-1, 96, 4, 4]               0
#           Conv2d-109            [-1, 576, 4, 4]          55,296
#      BatchNorm2d-110            [-1, 576, 4, 4]           1,152
#            ReLU6-111            [-1, 576, 4, 4]               0
#           Conv2d-112            [-1, 576, 4, 4]           5,184
#      BatchNorm2d-113            [-1, 576, 4, 4]           1,152
#            ReLU6-114            [-1, 576, 4, 4]               0
#           Conv2d-115             [-1, 96, 4, 4]          55,296
#      BatchNorm2d-116             [-1, 96, 4, 4]             192
# InvertedResidual-117             [-1, 96, 4, 4]               0
#           Conv2d-118            [-1, 576, 4, 4]          55,296
#      BatchNorm2d-119            [-1, 576, 4, 4]           1,152
#            ReLU6-120            [-1, 576, 4, 4]               0
#           Conv2d-121            [-1, 576, 2, 2]           5,184
#      BatchNorm2d-122            [-1, 576, 2, 2]           1,152
#            ReLU6-123            [-1, 576, 2, 2]               0
#           Conv2d-124            [-1, 160, 2, 2]          92,160
#      BatchNorm2d-125            [-1, 160, 2, 2]             320
# InvertedResidual-126            [-1, 160, 2, 2]               0
#           Conv2d-127            [-1, 960, 2, 2]         153,600
#      BatchNorm2d-128            [-1, 960, 2, 2]           1,920
#            ReLU6-129            [-1, 960, 2, 2]               0
#           Conv2d-130            [-1, 960, 2, 2]           8,640
#      BatchNorm2d-131            [-1, 960, 2, 2]           1,920
#            ReLU6-132            [-1, 960, 2, 2]               0
#           Conv2d-133            [-1, 160, 2, 2]         153,600
#      BatchNorm2d-134            [-1, 160, 2, 2]             320
# InvertedResidual-135            [-1, 160, 2, 2]               0
#           Conv2d-136            [-1, 960, 2, 2]         153,600
#      BatchNorm2d-137            [-1, 960, 2, 2]           1,920
#            ReLU6-138            [-1, 960, 2, 2]               0
#           Conv2d-139            [-1, 960, 2, 2]           8,640
#      BatchNorm2d-140            [-1, 960, 2, 2]           1,920
#            ReLU6-141            [-1, 960, 2, 2]               0
#           Conv2d-142            [-1, 160, 2, 2]         153,600
#      BatchNorm2d-143            [-1, 160, 2, 2]             320
# InvertedResidual-144            [-1, 160, 2, 2]               0
#           Conv2d-145            [-1, 960, 2, 2]         153,600
#      BatchNorm2d-146            [-1, 960, 2, 2]           1,920
#            ReLU6-147            [-1, 960, 2, 2]               0
#           Conv2d-148            [-1, 960, 2, 2]           8,640
#      BatchNorm2d-149            [-1, 960, 2, 2]           1,920
#            ReLU6-150            [-1, 960, 2, 2]               0
#           Conv2d-151            [-1, 320, 2, 2]         307,200
#      BatchNorm2d-152            [-1, 320, 2, 2]             640
# InvertedResidual-153            [-1, 320, 2, 2]               0
#           Conv2d-154           [-1, 1280, 2, 2]         409,600
#      BatchNorm2d-155           [-1, 1280, 2, 2]           2,560
#            ReLU6-156           [-1, 1280, 2, 2]               0
#          Dropout-157                 [-1, 1280]               0
#           Linear-158                    [-1, 2]           2,562
# ================================================================
# Total params: 2,226,434
# Trainable params: 2,226,434
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.05
# Forward/backward pass size (MB): 12.49
# Params size (MB): 8.49
# Estimated Total Size (MB): 21.03
# ----------------------------------------------------------------

# %%
# Load data
img = np.array(Image.open(IMAGE_FILE).convert("YCbCr"))
coords, _, _ = image.slide2d(sz=img.shape[:2], K=64, S=32)
patches = image.crop_patches( img=img, coords=coords, patch_sz=64)
loader = NumpyImageLoader( ndarray_data=patches, batch_size=1, n_workers=cpu_count(), pin_memory=True, shuffle=False).loader

# Measure time
times = []
for X in loader:
    X = X[0].to(DEVICE)
    start_time = time()
    logits = model(X)
    end_time = time()
    times.append(end_time-start_time)
    
print("Runtime: %.1f[ms]" % (1000*sum(times)/len(times)))
# Out:
# Runtime: 5.8[ms]

# %% [markdown]
# # MobileNetV2_mod

# %%
from utils.models import MobileNetV2

params["channel"] = "YCbCr"
params["threshold"] = 0.645
params["training_log_dir"] = "../backup/MBN2-mod-YCbCr/checkpoints/"

MODEL_FILE = os.path.join(params["training_log_dir"], "model.ckpt")
DEVICE = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

model = MobileNetV2(n_classes=2).to(device=DEVICE)
model.load(model_file=MODEL_FILE)
model.eval()
summary(model, input_size=(3, 64, 64))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1           [-1, 32, 64, 64]             864
#        BatchNorm2d-2           [-1, 32, 64, 64]              64
#             Conv2d-3           [-1, 32, 64, 64]           1,024
#        BatchNorm2d-4           [-1, 32, 64, 64]              64
#             Conv2d-5           [-1, 32, 64, 64]             288
#        BatchNorm2d-6           [-1, 32, 64, 64]              64
#             Conv2d-7           [-1, 16, 64, 64]             512
#        BatchNorm2d-8           [-1, 16, 64, 64]              32
#             Conv2d-9           [-1, 16, 64, 64]             512
#       BatchNorm2d-10           [-1, 16, 64, 64]              32
#             Block-11           [-1, 16, 64, 64]               0
#            Conv2d-12           [-1, 96, 64, 64]           1,536
#       BatchNorm2d-13           [-1, 96, 64, 64]             192
#            Conv2d-14           [-1, 96, 64, 64]             864
#       BatchNorm2d-15           [-1, 96, 64, 64]             192
#            Conv2d-16           [-1, 24, 64, 64]           2,304
#       BatchNorm2d-17           [-1, 24, 64, 64]              48
#            Conv2d-18           [-1, 24, 64, 64]             384
#       BatchNorm2d-19           [-1, 24, 64, 64]              48
#             Block-20           [-1, 24, 64, 64]               0
#            Conv2d-21          [-1, 144, 64, 64]           3,456
#       BatchNorm2d-22          [-1, 144, 64, 64]             288
#            Conv2d-23          [-1, 144, 64, 64]           1,296
#       BatchNorm2d-24          [-1, 144, 64, 64]             288
#            Conv2d-25           [-1, 24, 64, 64]           3,456
#       BatchNorm2d-26           [-1, 24, 64, 64]              48
#             Block-27           [-1, 24, 64, 64]               0
#            Conv2d-28          [-1, 144, 64, 64]           3,456
#       BatchNorm2d-29          [-1, 144, 64, 64]             288
#            Conv2d-30          [-1, 144, 32, 32]           1,296
#       BatchNorm2d-31          [-1, 144, 32, 32]             288
#            Conv2d-32           [-1, 32, 32, 32]           4,608
#       BatchNorm2d-33           [-1, 32, 32, 32]              64
#             Block-34           [-1, 32, 32, 32]               0
#            Conv2d-35          [-1, 192, 32, 32]           6,144
#       BatchNorm2d-36          [-1, 192, 32, 32]             384
#            Conv2d-37          [-1, 192, 32, 32]           1,728
#       BatchNorm2d-38          [-1, 192, 32, 32]             384
#            Conv2d-39           [-1, 32, 32, 32]           6,144
#       BatchNorm2d-40           [-1, 32, 32, 32]              64
#             Block-41           [-1, 32, 32, 32]               0
#            Conv2d-42          [-1, 192, 32, 32]           6,144
#       BatchNorm2d-43          [-1, 192, 32, 32]             384
#            Conv2d-44          [-1, 192, 32, 32]           1,728
#       BatchNorm2d-45          [-1, 192, 32, 32]             384
#            Conv2d-46           [-1, 32, 32, 32]           6,144
#       BatchNorm2d-47           [-1, 32, 32, 32]              64
#             Block-48           [-1, 32, 32, 32]               0
#            Conv2d-49          [-1, 192, 32, 32]           6,144
#       BatchNorm2d-50          [-1, 192, 32, 32]             384
#            Conv2d-51          [-1, 192, 16, 16]           1,728
#       BatchNorm2d-52          [-1, 192, 16, 16]             384
#            Conv2d-53           [-1, 64, 16, 16]          12,288
#       BatchNorm2d-54           [-1, 64, 16, 16]             128
#             Block-55           [-1, 64, 16, 16]               0
#            Conv2d-56          [-1, 384, 16, 16]          24,576
#       BatchNorm2d-57          [-1, 384, 16, 16]             768
#            Conv2d-58          [-1, 384, 16, 16]           3,456
#       BatchNorm2d-59          [-1, 384, 16, 16]             768
#            Conv2d-60           [-1, 64, 16, 16]          24,576
#       BatchNorm2d-61           [-1, 64, 16, 16]             128
#             Block-62           [-1, 64, 16, 16]               0
#            Conv2d-63          [-1, 384, 16, 16]          24,576
#       BatchNorm2d-64          [-1, 384, 16, 16]             768
#            Conv2d-65          [-1, 384, 16, 16]           3,456
#       BatchNorm2d-66          [-1, 384, 16, 16]             768
#            Conv2d-67           [-1, 64, 16, 16]          24,576
#       BatchNorm2d-68           [-1, 64, 16, 16]             128
#             Block-69           [-1, 64, 16, 16]               0
#            Conv2d-70          [-1, 384, 16, 16]          24,576
#       BatchNorm2d-71          [-1, 384, 16, 16]             768
#            Conv2d-72          [-1, 384, 16, 16]           3,456
#       BatchNorm2d-73          [-1, 384, 16, 16]             768
#            Conv2d-74           [-1, 64, 16, 16]          24,576
#       BatchNorm2d-75           [-1, 64, 16, 16]             128
#             Block-76           [-1, 64, 16, 16]               0
#            Conv2d-77          [-1, 384, 16, 16]          24,576
#       BatchNorm2d-78          [-1, 384, 16, 16]             768
#            Conv2d-79          [-1, 384, 16, 16]           3,456
#       BatchNorm2d-80          [-1, 384, 16, 16]             768
#            Conv2d-81           [-1, 96, 16, 16]          36,864
#       BatchNorm2d-82           [-1, 96, 16, 16]             192
#            Conv2d-83           [-1, 96, 16, 16]           6,144
#       BatchNorm2d-84           [-1, 96, 16, 16]             192
#             Block-85           [-1, 96, 16, 16]               0
#            Conv2d-86          [-1, 576, 16, 16]          55,296
#       BatchNorm2d-87          [-1, 576, 16, 16]           1,152
#            Conv2d-88          [-1, 576, 16, 16]           5,184
#       BatchNorm2d-89          [-1, 576, 16, 16]           1,152
#            Conv2d-90           [-1, 96, 16, 16]          55,296
#       BatchNorm2d-91           [-1, 96, 16, 16]             192
#             Block-92           [-1, 96, 16, 16]               0
#            Conv2d-93          [-1, 576, 16, 16]          55,296
#       BatchNorm2d-94          [-1, 576, 16, 16]           1,152
#            Conv2d-95          [-1, 576, 16, 16]           5,184
#       BatchNorm2d-96          [-1, 576, 16, 16]           1,152
#            Conv2d-97           [-1, 96, 16, 16]          55,296
#       BatchNorm2d-98           [-1, 96, 16, 16]             192
#             Block-99           [-1, 96, 16, 16]               0
#           Conv2d-100          [-1, 576, 16, 16]          55,296
#      BatchNorm2d-101          [-1, 576, 16, 16]           1,152
#           Conv2d-102            [-1, 576, 8, 8]           5,184
#      BatchNorm2d-103            [-1, 576, 8, 8]           1,152
#           Conv2d-104            [-1, 160, 8, 8]          92,160
#      BatchNorm2d-105            [-1, 160, 8, 8]             320
#            Block-106            [-1, 160, 8, 8]               0
#           Conv2d-107            [-1, 960, 8, 8]         153,600
#      BatchNorm2d-108            [-1, 960, 8, 8]           1,920
#           Conv2d-109            [-1, 960, 8, 8]           8,640
#      BatchNorm2d-110            [-1, 960, 8, 8]           1,920
#           Conv2d-111            [-1, 160, 8, 8]         153,600
#      BatchNorm2d-112            [-1, 160, 8, 8]             320
#            Block-113            [-1, 160, 8, 8]               0
#           Conv2d-114            [-1, 960, 8, 8]         153,600
#      BatchNorm2d-115            [-1, 960, 8, 8]           1,920
#           Conv2d-116            [-1, 960, 8, 8]           8,640
#      BatchNorm2d-117            [-1, 960, 8, 8]           1,920
#           Conv2d-118            [-1, 160, 8, 8]         153,600
#      BatchNorm2d-119            [-1, 160, 8, 8]             320
#            Block-120            [-1, 160, 8, 8]               0
#           Conv2d-121            [-1, 960, 8, 8]         153,600
#      BatchNorm2d-122            [-1, 960, 8, 8]           1,920
#           Conv2d-123            [-1, 960, 8, 8]           8,640
#      BatchNorm2d-124            [-1, 960, 8, 8]           1,920
#           Conv2d-125            [-1, 320, 8, 8]         307,200
#      BatchNorm2d-126            [-1, 320, 8, 8]             640
#           Conv2d-127            [-1, 320, 8, 8]          51,200
#      BatchNorm2d-128            [-1, 320, 8, 8]             640
#            Block-129            [-1, 320, 8, 8]               0
#           Conv2d-130           [-1, 1280, 8, 8]         409,600
#      BatchNorm2d-131           [-1, 1280, 8, 8]           2,560
#           Linear-132                    [-1, 2]           2,562
# ================================================================
# Total params: 2,286,674
# Trainable params: 2,286,674
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.05
# Forward/backward pass size (MB): 109.48
# Params size (MB): 8.72
# Estimated Total Size (MB): 118.25
# ----------------------------------------------------------------

# %%
# Load data
img = np.array(Image.open(IMAGE_FILE).convert("YCbCr"))
coords, _, _ = image.slide2d(sz=img.shape[:2], K=64, S=32)
patches = image.crop_patches( img=img, coords=coords, patch_sz=64)
loader = NumpyImageLoader(ndarray_data=patches, batch_size=1, n_workers=cpu_count(), pin_memory=True, shuffle=False).loader

# Measure time
times = []
for X in loader:
    X = X[0].to(DEVICE)
    start_time = time()
    logits = model(X)
    end_time = time()
    times.append(end_time-start_time)
    
print("Runtime: %.1f[ms]" % (1000*sum(times)/len(times)))
# Out:
# Runtime: 6.2[ms]
